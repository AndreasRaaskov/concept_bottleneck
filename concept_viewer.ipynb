# %%
import os
import matplotlib.pyplot as plt
import torchvision
import torch
import pandas as pd
import numpy as np

from data_loaders import CUB_extnded_dataset
from IPython.display import display
from utils.notebook import display_scrollable_dataframe

# %%
# Settings for the experiment your running
data_set = 'test' 


majority_config = {'CUB_dir':r'data/CUB_200_2011',
                'split_file':r'data/train_test_val.pkl',
                'use_majority_voting':True,
                'min_class_count':10,
                'return_visibility':False}

All_concept_config = {'CUB_dir':r'data/CUB_200_2011',
                'split_file':r'data/train_test_val.pkl',
                'use_majority_voting':True,
                'min_class_count':0,
                'return_visibility':False}

Majority_dataset = CUB_extnded_dataset(mode=data_set,config_dict=majority_config,transform=None)
All_concept_dataset = CUB_extnded_dataset(mode=data_set,config_dict=All_concept_config,transform=None)

# %%
bird_id_1 = 45
bird_id_2 = 86
name_1 = Majority_dataset.class_labels_names[bird_id_1]
C_bird1 = Majority_dataset.concepts[bird_id_1]

name_2 = Majority_dataset.class_labels_names[bird_id_2]
C_bird2 = Majority_dataset.concepts[bird_id_2]

Concept_dict={"Concept":Majority_dataset.consept_labels_names,
                    name_1: C_bird1,
                    name_2: C_bird2
                      }

df = pd.DataFrame(Concept_dict)
display_scrollable_dataframe(df[df[name_1] != df[name_2]])
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>046.Gadwall</th>
#       <th>087.Mallard</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>has_wing_color::brown</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>has_wing_color::white</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>has_wing_color::buff</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>has_upperparts_color::grey</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>has_upperparts_color::white</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
# ...

# %%
bird_id_1 = 28
bird_id_2 = 29
name_1 = Majority_dataset.class_labels_names[bird_id_1]
C_bird1 = Majority_dataset.concepts[bird_id_1]

name_2 = Majority_dataset.class_labels_names[bird_id_2]
C_bird2 = Majority_dataset.concepts[bird_id_2]

Concept_dict={"Concept":Majority_dataset.consept_labels_names,
                    name_1: C_bird1,
                    name_2: C_bird2
                      }

df = pd.DataFrame(Concept_dict)
display_scrollable_dataframe(df[df[name_1] != df[name_2]])
display_scrollable_dataframe(df)
print(np.mean(C_bird1==C_bird2))
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>029.American_Crow</th>
#       <th>030.Fish_Crow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>76</th>
#       <td>has_wing_shape::rounded-wings</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>has_size::medium_(9_-_16_in)</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>029.American_Crow</th>
#       <th>030.Fish_Crow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
bird_id_1 = 28
bird_id_2 = 86
name_1 = Majority_dataset.class_labels_names[bird_id_1]
C_bird1 = Majority_dataset.concepts[bird_id_1]

name_2 = Majority_dataset.class_labels_names[bird_id_2]
C_bird2 = Majority_dataset.concepts[bird_id_2]

Concept_dict={"Concept":Majority_dataset.consept_labels_names,
                    name_1: C_bird1,
                    name_2: C_bird2
                      }

df = pd.DataFrame(Concept_dict)
display_scrollable_dataframe(df[df[name_1] != df[name_2]])
display_scrollable_dataframe(df)
print(np.sum(C_bird1!=C_bird2))
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>029.American_Crow</th>
#       <th>087.Mallard</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>has_bill_shape::all-purpose</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>has_wing_color::black</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>has_wing_color::white</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>has_upperparts_color::brown</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>has_upperparts_color::black</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
# ...

# %%
bird_id_1 = 101
bird_id_2 = 118
name_1 = Majority_dataset.class_labels_names[bird_id_1]
C_bird1 = Majority_dataset.concepts[bird_id_1]

name_2 = Majority_dataset.class_labels_names[bird_id_2]
C_bird2 = Majority_dataset.concepts[bird_id_2]

Concept_dict={"Concept":Majority_dataset.consept_labels_names,
                    name_1: C_bird1,
                    name_2: C_bird2
                      }

df = pd.DataFrame(Concept_dict)
display_scrollable_dataframe(df)
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>102.Western_Wood_Pewee</th>
#       <th>119.Field_Sparrow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>has_bill_shape::dagger</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>has_bill_shape::hooked_seabird</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>has_bill_shape::all-purpose</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>has_bill_shape::cone</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>has_wing_color::brown</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
bird_id_1 = 124
bird_id_2 = 128
name_1 = Majority_dataset.class_labels_names[bird_id_1]
C_bird1 = Majority_dataset.concepts[bird_id_1]

name_2 = Majority_dataset.class_labels_names[bird_id_2]
C_bird2 = Majority_dataset.concepts[bird_id_2]

Concept_dict={"Concept":Majority_dataset.consept_labels_names,
                    name_1: C_bird1,
                    name_2: C_bird2
                      }

df = pd.DataFrame(Concept_dict)
display_scrollable_dataframe(df[df[name_1] != df[name_2]])
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>125.Lincoln_Sparrow</th>
#       <th>129.Song_Sparrow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>has_wing_color::black</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>has_wing_color::buff</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>has_upperparts_color::grey</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>has_upperparts_color::black</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>has_underparts_color::brown</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
# ...

# %%
#Print length of the dataset
print(CUB_extnded_dataset(mode="train",config_dict=majority_config,transform=None).__len__())
print(CUB_extnded_dataset(mode="val",config_dict=majority_config,transform=None).__len__())
print(CUB_extnded_dataset(mode="test",config_dict=majority_config,transform=None).__len__())
# Out:
# 4796
# 1198
# 5794

# %%
np.sum(Majority_dataset.concepts,axis=0)
# Out:
# array([ 17,  12,  81,  49,  49,  46,  12,  82,  41,  26,  46,  54,  16,
#         82,  35,  25,  12,  20,  28,  31,  86,  29, 129,  15,  16,  45,
#         51,  10,  54,  24,  22,  58,  34,  36,  61,  24,  17,  10,  43,
#         13,  18,  29,  33,  74,  24,  10,  21,  40,  74,  13, 192,  68,
#        126,  10,  28,  23,  15,  68,  17,  30,  30,  78,  32,  17,  26,
#         33,  12,  46,  37,  17,  11,  17,  29,  25,  82,  23,  85,  30,
#        126,  37,  19,  10, 119,  99,  24,  14,  86,  13,  26, 149,  38,
#         43,  25,  56,  41,  18,  45,  55,  22,  25,  98,  11,  10,  29,
#         23,  11,  67,  15,  54,  10,  40,  44])

# %%
np.sum(All_concept_dataset.concepts,axis=1)
# Out:
# array([ 9, 22, 21, 25, 28, 29, 23, 24, 25, 26, 19, 25, 29, 25, 27, 20, 25,
#        17, 26, 20, 26, 24, 25, 23, 24, 25, 28, 25, 26, 24, 25, 18, 22, 35,
#        14, 27, 18, 26, 20, 22, 24, 21, 15, 23, 24, 26, 30, 34, 24, 28, 13,
#        17, 28, 27, 29, 19, 29, 28, 27, 27, 25, 28, 24, 26, 24, 29, 11, 10,
#        16, 24, 24, 14, 26, 21, 26, 20, 22, 26, 26, 18, 33, 12, 31, 27, 26,
#        19, 22, 22, 17, 26, 19, 27, 27, 24, 29, 27, 23, 31, 17,  7, 23, 26,
#        14, 29, 19, 26, 24, 23, 28, 28, 32, 27, 33, 26, 23, 26, 36, 25, 24,
#        26, 30, 30, 35, 25, 48, 28, 29, 11, 30, 30, 22, 24, 33, 36, 20, 21,
#        17, 27, 27, 27, 20, 21, 24, 27, 27, 28, 28, 21, 30, 24, 24, 24, 24,
#        22, 25, 31, 25, 29, 34, 22, 30, 17, 15, 21, 25, 27, 22, 18, 30, 20,
#        26, 26, 14, 12, 25, 25, 30, 28, 24, 27, 27, 24, 28, 24, 31, 29, 29,
#        29, 31, 33, 30, 33, 23, 39, 29, 30, 27, 26, 28, 21])

# %%
Majority_dataset.class_labels_names[np.argsort(np.sum(All_concept_dataset.concepts,axis=1))]
# Out:
# array(['100.Brown_Pelican', '001.Black_footed_Albatross',
#        '068.Ruby_throated_Hummingbird', '128.Seaside_Sparrow',
#        '067.Anna_Hummingbird', '082.Ringed_Kingfisher',
#        '174.Palm_Warbler', '051.Horned_Grebe', '103.Sayornis',
#        '072.Pomarine_Jaeger', '173.Orange_crowned_Warbler',
#        '035.Purple_Finch', '043.Yellow_bellied_Flycatcher',
#        '163.Cape_May_Warbler', '069.Rufous_Hummingbird',
#        '052.Pied_billed_Grebe', '137.Cliff_Swallow',
#        '018.Spotted_Catbird', '089.Hooded_Merganser',
#        '162.Canada_Warbler', '099.Ovenbird', '032.Mangrove_Cuckoo',
#        '037.Acadian_Flycatcher', '080.Green_Kingfisher',
#        '168.Kentucky_Warbler', '011.Rusty_Blackbird',
#        '105.Whip_poor_Will', '056.Pine_Grosbeak', '091.Mockingbird',
#        '086.Pacific_Loon', '020.Yellow_breasted_Chat',
#        '076.Dark_eyed_Junco', '135.Bank_Swallow', '141.Artic_Tern',
#        '016.Painted_Bunting', '039.Least_Flycatcher',
# ...

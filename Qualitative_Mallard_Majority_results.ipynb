# %% [markdown]
# A note book for documenting qualitative results

# %%
import os
import matplotlib.pyplot as plt
import torchvision
import torch
import pandas as pd
import numpy as np

from models import get_inception_transform
from data_loaders import CUB_extnded_dataset,CUB_CtoY_dataset
from IPython.display import display
from utils.notebook import display_scrollable_dataframe,plot_sailency
from sailency import get_saliency_maps,saliency_score_part

# %%
# Settings for the experiment your running
data_set = 'test' 

#Make the dataset
transform = get_inception_transform(mode=data_set, methode= "center")

majority_config = {'CUB_dir':r'data/CUB_200_2011',
                'split_file':r'data/train_test_val.pkl',
                'use_majority_voting':True,
                'min_class_count':10,
                'return_visibility':False}

NoN_majority_config = {'CUB_dir':r'data/CUB_200_2011',
                'split_file':r'data/train_test_val.pkl',
                'use_majority_voting':False,
                'min_class_count':10,
                'return_visibility':False}

Non_majority_data_set = CUB_extnded_dataset(mode=data_set,config_dict=NoN_majority_config,transform=transform)



#Make the majority dataset and find the mask, we use CtoY dataset so we only need to loade the image ones 
Majority_dataset = CUB_CtoY_dataset(mode=data_set,config_dict=majority_config,transform=transform)
mask = Majority_dataset.concept_mask

#Make dataloader that return non standarized images
human_tansform = torchvision.transforms.Compose([torchvision.transforms.CenterCrop(299),torchvision.transforms.ToTensor()])
data_human = CUB_extnded_dataset(mode=data_set,config_dict=majority_config,transform=human_tansform)

#Define usefull variables
concept_names = data_human.consept_labels_names
class_names = data_human.class_labels_names
n_classes = data_human.n_classes
n_concepts = data_human.n_concepts

print(f"Number of classes: {n_classes}")
print(f"Number of concepts: {n_concepts}")
# Out:
# Number of classes: 200
# Number of concepts: 112

# %%
#Find all idx for a class
class_id = 86

class_list = []
for i in range(len(Majority_dataset)):
    C,Y = Majority_dataset.__getitem__(i)
    Y = torch.argmax(Y)
    if Y == class_id:
        class_list.append(i)
print(class_list)
# Out:
# [2445, 2446, 2447, 2448, 2449, 2450, 2451, 2452, 2453, 2454, 2455, 2456, 2457, 2458, 2459, 2460, 2461, 2462, 2463, 2464, 2465, 2466, 2467, 2468, 2469, 2470, 2471, 2472, 2473, 2474]

# %%
# Genrate the dataset
#picturer_idx = 2455
picturer_idx = 2463
#picturer_idx = 2454 #Gadwell

img ,_,Y,coordinates = data_human.__getitem__(picturer_idx)

# Show the image and the coordinates of the concepts
plt.imshow(img.permute(1, 2, 0))
plt.title(f"Class: {class_names[torch.argmax(Y)]}")
for i in range(len(coordinates)):
    if len(coordinates[i]) > 0:

        for x,y in coordinates[i]:
            #plt.plot(x,y,'ro')
            name=concept_names[i].split("_")[1]
            if name == "forehead":
                ofset = -30

            elif name == "eye":
                ofset = 0
            else:
                ofset = 0
            
            plt.text(x+ofset,y,name,fontsize=9,color='red')
    plt.axis('off')
            
plt.size=(50,50)
plt.show()

#Load the data
X, C, Y,_ = Non_majority_data_set.__getitem__(picturer_idx)

# Separate the concepts and their visibility only relevant if visibility is used and no majority voting is used
if len(C.shape) == 2:
    Concepts = C[0]
    Concepts_visiblity = C[1]
else:
    Concepts = C.tolist()
    Concepts_visiblity = [None]*len(C)

X = X.unsqueeze(0)

# %%
#Make concept dictionary
"""
concept_prediction = concept_prediction[0].detach()
concepts_propebability = torch.sigmoid(concept_prediction)
pridicted_class = Majority_dataset.concepts[Y]
#Apply mask
if concept_prediction.shape != Majority_C.shape:
    concept_prediction = concept_prediction[mask]
    concepts_propebability = concepts_propebability[mask]
"""


#Get ture labels 
_,NoN_Majority_C,_,_ = Non_majority_data_set.__getitem__(picturer_idx)
Majority_C,_ = Majority_dataset.__getitem__(picturer_idx)

#Find distribution of the concepts
Majority_concepts = Majority_dataset.concepts
NoN_Majority_concepts = np.array([Non_majority_data_set.concepts[y] for y in Non_majority_data_set.concepts.keys()])


Concept_dict={"Concept":concept_names,
                    "Label": NoN_Majority_C[mask].numpy().astype(bool),
                    #"Label distribution": np.mean(NoN_Majority_concepts,axis=0)[mask],
                    "Majority Label": Majority_C.numpy().astype(bool),
                    #"Majority ditribution": np.mean(Majority_concepts,axis=0)
                      }

# %%
#Test majority joint model
model_path = r'Majority_models\Joint_CKPT_Majority\best_Joint_model.pth'

#Load the model
Joint_model = torch.load(model_path,map_location=torch.device('cpu'),weights_only=False)
Joint_model.eval()
Joint_model.use_sigmoid = True

#Make prediction
C_hat,Y_hat = Joint_model(X)
C_hat_probability = torch.sigmoid(C_hat)
Y_hat = torch.softmax(Y_hat,dim=1)
print(f"Predicted class: {class_names[Y_hat.argmax().item()]} true class: {class_names[Y.argmax().item()]} probability of true class: {Y_hat[0,Y.argmax()].item()}")

#Make Concept prediction and other stuff
weights = Joint_model.CtoY_model.linear.weight[Y.argmax().item()]
Concept_dict["Joint MV"] = np.round(C_hat_probability.detach().numpy()[0],2)
#display_scrollable_dataframe(pd.DataFrame(Concept_dict))
# Out:
# Predicted class: 087.Mallard true class: 087.Mallard probability of true class: 0.010462209582328796

# %%
#Test NoN majority joint model
model_path = r'NoMajority_models\Joint_CKPT_NoMajority\best_Joint_model.pth'

#Load the model
Joint_model = torch.load(model_path,map_location=torch.device('cpu'),weights_only=False)
Joint_model.eval()
Joint_model.use_sigmoid = True

#Make prediction
C_hat,Y_hat = Joint_model(X)
C_hat_probability = torch.sigmoid(C_hat)
Y_hat = torch.softmax(Y_hat,dim=1)
print(f"Predicted class: {class_names[Y_hat.argmax().item()]} true class: {class_names[Y.argmax().item()]} probability of true class: {Y_hat[0,Y.argmax()].item()}")

#Make Concept prediction and other stuff
weights = Joint_model.CtoY_model.linear.weight[Y.argmax().item()]
Concept_dict["Joint NoN-MV"] = np.round(C_hat_probability.detach().numpy()[0][mask],2)
#display_scrollable_dataframe(pd.DataFrame(Concept_dict).sort_values(by=['Joint NonMajority prediction'],ascending=False))
# Out:
# Predicted class: 087.Mallard true class: 087.Mallard probability of true class: 0.011519829742610455

# %%
# Test the concept model with majority voting
XtoC_Model = torch.load(r'Majority_models\Concepts_CKPT_Majority\best_XtoC_model.pth',map_location=torch.device('cpu'),weights_only=False)
XtoC_Model.eval()

CtoY_Model = torch.load(r'Majority_models\Sequential_CtoY_CKPT_majority\best_CtoY_model.pth',map_location=torch.device('cpu'),weights_only=False)
CtoY_Model.eval()
CtoY_model = CtoY_Model.float()

#Make prediction
C_hat = XtoC_Model(X)
C_hat_probability = torch.sigmoid(C_hat)

Y_hat = torch.softmax(CtoY_Model(C_hat_probability),dim=1)

print(f"Predicted class: {class_names[Y_hat.argmax().item()]} true class: {class_names[Y.argmax().item()]} probability of true class: {Y_hat[0,Y.argmax()].item()}")

#Make Concept prediction and other stuff
weights = CtoY_Model.linear.weight[Y.argmax().item()]

Concept_dict["Sequential MV"] = np.round(C_hat_probability.detach().numpy()[0],2)
#display_scrollable_dataframe(pd.DataFrame(Concept_dict).sort_values(by=['Majority Label',"Label"],ascending=False))
# Out:
# Predicted class: 087.Mallard true class: 087.Mallard probability of true class: 0.9995344877243042

# %%
# Test the concept model with NoN majority voting
XtoC_Model = torch.load(r'NoMajority_models\Concepts_CKPT_NoMajority\best_XtoC_model.pth',map_location=torch.device('cpu'),weights_only=False)
XtoC_Model.eval()

CtoY_Model = torch.load(r'NoMajority_models\Sequential_CKTP_NoPretraining\best_CtoY_model.pth',map_location=torch.device('cpu'),weights_only=False)
CtoY_Model.eval()
CtoY_model = CtoY_Model.float()

#Make prediction
C_hat = XtoC_Model(X)
C_hat_probability = torch.sigmoid(C_hat)

Y_hat = torch.softmax(CtoY_Model(C_hat_probability),dim=1)

print(f"Predicted class: {class_names[Y_hat.argmax().item()]} true class: {class_names[Y.argmax().item()]} probability of true class: {Y_hat[0,Y.argmax()].item()}")

#Make Concept prediction and other stuff
weights = CtoY_Model.linear.weight[Y.argmax().item()]

Concept_dict["Sequential NoN-MV"] = np.round(C_hat_probability.detach().numpy()[0][mask],2)
#display_scrollable_dataframe(pd.DataFrame(Concept_dict).sort_values(by=['Majority Label',"Label"],ascending=False))
# Out:
# Predicted class: 087.Mallard true class: 087.Mallard probability of true class: 1.0

# %%
#Add the baslines
Concept_dict["NoN-MV Label distribution"] = np.mean(NoN_Majority_concepts,axis=0)[mask]
Concept_dict["MV label ditribution"] = np.mean(Majority_concepts,axis=0)

# %%
Full_df=pd.DataFrame(Concept_dict)
Selected_df = Full_df[Full_df["Label"] != Full_df["Majority Label"]]

# add row 39 to selected
#Selected_df = pd.concat([Selected_df,Full_df.iloc[[39,8,51]]])

display_scrollable_dataframe(Selected_df)
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>Label</th>
#       <th>Majority Label</th>
#       <th>Joint MV</th>
#       <th>Joint NoN-MV</th>
#       <th>Sequential MV</th>
#       <th>Sequential NoN-MV</th>
#       <th>NoN-MV Label distribution</th>
#       <th>MV label ditribution</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>has_wing_color::brown</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.62</td>
#       <td>0.0</td>
#       <td>0.57</td>
#       <td>0.269681</td>
#       <td>0.245</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>has_wing_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.45</td>
#       <td>0.0</td>
#       <td>0.47</td>
#       <td>0.182474</td>
#       <td>0.130</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>has_upperparts_color::brown</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.64</td>
#       <td>1.0</td>
#       <td>0.67</td>
#       <td>0.243468</td>
#       <td>0.230</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>has_upperparts_color::black</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.54</td>
#       <td>0.0</td>
#       <td>0.63</td>
#       <td>0.391245</td>
#       <td>0.410</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>has_breast_pattern::solid</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.49</td>
#       <td>1.0</td>
#       <td>0.38</td>
#       <td>0.548269</td>
#       <td>0.645</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>has_breast_pattern::striped</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.117153</td>
#       <td>0.075</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>has_back_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.68</td>
#       <td>0.0</td>
#       <td>0.28</td>
#       <td>0.153800</td>
#       <td>0.120</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>has_back_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.53</td>
#       <td>0.0</td>
#       <td>0.52</td>
#       <td>0.146335</td>
#       <td>0.110</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>has_upper_tail_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.23</td>
#       <td>0.0</td>
#       <td>0.58</td>
#       <td>0.123940</td>
#       <td>0.120</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>has_eye_color::black</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>1.0</td>
#       <td>0.96</td>
#       <td>0.837462</td>
#       <td>0.960</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>has_forehead_color::blue</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.050814</td>
#       <td>0.050</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>has_under_tail_color::white</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>1.0</td>
#       <td>0.65</td>
#       <td>0.179080</td>
#       <td>0.160</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>has_back_pattern::multi-colored</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>1.0</td>
#       <td>0.41</td>
#       <td>0.194774</td>
#       <td>0.070</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>has_belly_pattern::solid</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.17</td>
#       <td>1.0</td>
#       <td>0.35</td>
#       <td>0.573465</td>
#       <td>0.745</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>has_primary_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.67</td>
#       <td>0.0</td>
#       <td>0.55</td>
#       <td>0.290126</td>
#       <td>0.205</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>has_primary_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.13</td>
#       <td>0.0</td>
#       <td>0.19</td>
#       <td>0.191975</td>
#       <td>0.090</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>has_crown_color::blue</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.02</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.054971</td>
#       <td>0.050</td>
#     </tr>
#   </tbody>
# </table>
#         </div>

# %%
concept_list = [85,22,50]

XtoC_Model = torch.load(r'Majority_models\Concepts_CKPT_Majority\best_XtoC_model.pth',map_location=torch.device('cpu'),weights_only=False)
XtoC_Model.eval()

sailency_maps = get_saliency_maps(X,concept_list,XtoC_Model,method_type='noise_tunnel')

plot_sailency(img,sailency_maps,concept_list,concept_names,coordinates)

# %%
XtoC_Model = torch.load(r'NoMajority_models\Concepts_CKPT_NoMajority\best_XtoC_model.pth',map_location=torch.device('cpu'),weights_only=False)
XtoC_Model.eval()

#Make temps names
#coordinates_temp = [coordinates[i] for i in mask]
#concept_names_temp = concept_names[mask] 
sailency_maps = get_saliency_maps(X,mask[concept_list],XtoC_Model,method_type='noise_tunnel')

plot_sailency(img,sailency_maps,concept_list,concept_names,coordinates)

# %%
concept_list = [57]
XtoC_Model = torch.load(r'evaluate_models\Concepts_CKPT_NoMajority\best_XtoC_model.pth',map_location=torch.device('cpu'),weights_only=False)
XtoC_Model.eval()
sailency_maps = get_saliency_maps(X,concept_list,XtoC_Model,method_type='noise_tunnel')

plot_sailency(img,sailency_maps,concept_list,concept_names,coordinates)

# %%
#print full df
display_scrollable_dataframe(Full_df.sort_values(by=['Majority Label',"Label"],ascending=False))
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>Label</th>
#       <th>Majority Label</th>
#       <th>Joint MV</th>
#       <th>Joint NoN-MV</th>
#       <th>Sequential MV</th>
#       <th>Sequential NoN-MV</th>
#       <th>NoN-MV Label distribution</th>
#       <th>MV label ditribution</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>has_wing_color::white</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.97</td>
#       <td>1.0</td>
#       <td>0.85</td>
#       <td>0.260774</td>
#       <td>0.205</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>has_upperparts_color::white</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.93</td>
#       <td>1.0</td>
#       <td>0.80</td>
#       <td>0.232949</td>
#       <td>0.175</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>has_upperparts_color::buff</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.78</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>0.169410</td>
#       <td>0.125</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>has_underparts_color::brown</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.53</td>
#       <td>1.0</td>
#       <td>0.78</td>
#       <td>0.102732</td>
#       <td>0.060</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>has_upper_tail_color::black</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.63</td>
#       <td>1.0</td>
#       <td>0.68</td>
#       <td>0.256956</td>
#       <td>0.305</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>has_head_pattern::plain</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.66</td>
#       <td>1.0</td>
#       <td>0.92</td>
#       <td>0.263828</td>
#       <td>0.215</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>has_breast_color::brown</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.93</td>
#       <td>1.0</td>
#       <td>0.99</td>
#       <td>0.113590</td>
#       <td>0.065</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>has_bill_length::about_the_same_as_head</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.67</td>
#       <td>1.0</td>
#       <td>0.85</td>
#       <td>0.362233</td>
#       <td>0.340</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>has_size::medium_(9_-_16_in)</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>0.196386</td>
#       <td>0.185</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>has_shape::duck-like</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>0.061334</td>
#       <td>0.050</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>has_tail_pattern::solid</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.12</td>
#       <td>1.0</td>
#       <td>0.33</td>
#       <td>0.355616</td>
#       <td>0.430</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>has_wing_pattern::multi-colored</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.93</td>
#       <td>1.0</td>
#       <td>0.81</td>
#       <td>0.297336</td>
#       <td>0.220</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>has_upperparts_color::brown</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.64</td>
#       <td>1.0</td>
#       <td>0.67</td>
#       <td>0.243468</td>
#       <td>0.230</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>has_breast_pattern::solid</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.49</td>
#       <td>1.0</td>
#       <td>0.38</td>
#       <td>0.548269</td>
#       <td>0.645</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>has_eye_color::black</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>1.0</td>
#       <td>0.96</td>
#       <td>0.837462</td>
#       <td>0.960</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>has_under_tail_color::white</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>1.0</td>
#       <td>0.65</td>
#       <td>0.179080</td>
#       <td>0.160</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>has_back_pattern::multi-colored</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>1.0</td>
#       <td>0.41</td>
#       <td>0.194774</td>
#       <td>0.070</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>has_belly_pattern::solid</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.17</td>
#       <td>1.0</td>
#       <td>0.35</td>
#       <td>0.573465</td>
#       <td>0.745</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>has_wing_color::brown</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.62</td>
#       <td>0.0</td>
#       <td>0.57</td>
#       <td>0.269681</td>
#       <td>0.245</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>has_wing_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.45</td>
#       <td>0.0</td>
#       <td>0.47</td>
#       <td>0.182474</td>
#       <td>0.130</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>has_upperparts_color::black</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.54</td>
#       <td>0.0</td>
#       <td>0.63</td>
#       <td>0.391245</td>
#       <td>0.410</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>has_breast_pattern::striped</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.117153</td>
#       <td>0.075</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>has_back_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.68</td>
#       <td>0.0</td>
#       <td>0.28</td>
#       <td>0.153800</td>
#       <td>0.120</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>has_back_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.53</td>
#       <td>0.0</td>
#       <td>0.52</td>
#       <td>0.146335</td>
#       <td>0.110</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>has_upper_tail_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.23</td>
#       <td>0.0</td>
#       <td>0.58</td>
#       <td>0.123940</td>
#       <td>0.120</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>has_forehead_color::blue</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.050814</td>
#       <td>0.050</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>has_primary_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.67</td>
#       <td>0.0</td>
#       <td>0.55</td>
#       <td>0.290126</td>
#       <td>0.205</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>has_primary_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.13</td>
#       <td>0.0</td>
#       <td>0.19</td>
#       <td>0.191975</td>
#       <td>0.090</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>has_crown_color::blue</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.02</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.054971</td>
#       <td>0.050</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>has_bill_shape::dagger</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.134968</td>
#       <td>0.085</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>has_bill_shape::hooked_seabird</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.063709</td>
#       <td>0.060</td>
#     </tr>
#     <

# %%
print(Selected_df.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# Concept & Label & Majority Label & Joint MV & Joint NoN-MV & Sequential MV & Sequential NoN-MV & NoN-MV Label distribution & MV label ditribution \\
# \midrule
# has_wing_color::brown & True & False & 0.000000 & 0.620000 & 0.000000 & 0.570000 & 0.269681 & 0.245000 \\
# has_wing_color::buff & True & False & 0.000000 & 0.450000 & 0.000000 & 0.470000 & 0.182474 & 0.130000 \\
# has_upperparts_color::brown & False & True & 1.000000 & 0.640000 & 1.000000 & 0.670000 & 0.243468 & 0.230000 \\
# has_upperparts_color::black & True & False & 0.000000 & 0.540000 & 0.000000 & 0.630000 & 0.391245 & 0.410000 \\
# has_breast_pattern::solid & False & True & 1.000000 & 0.490000 & 1.000000 & 0.380000 & 0.548269 & 0.645000 \\
# has_breast_pattern::striped & True & False & 0.000000 & 0.010000 & 0.000000 & 0.050000 & 0.117153 & 0.075000 \\
# has_back_color::white & True & False & 0.000000 & 0.680000 & 0.000000 & 0.280000 & 0.153800 & 0.120000 \\
# has_back_color::buff & True & False & 0.000000 & 0.530000 & 0.000000 & 0.520000 & 0.146335 & 0.110000 \\
# has_upper_tail_color::white & True & False & 0.000000 & 0.230000 & 0.000000 & 0.580000 & 0.123940 & 0.120000 \\
# has_eye_color::black & False & True & 1.000000 & 0.980000 & 1.000000 & 0.960000 & 0.837462 & 0.960000 \\
# has_forehead_color::blue & True & False & 0.000000 & 0.010000 & 0.000000 & 0.010000 & 0.050814 & 0.050000 \\
# has_under_tail_color::white & False & True & 1.000000 & 0.740000 & 1.000000 & 0.650000 & 0.179080 & 0.160000 \\
# has_back_pattern::multi-colored & False & True & 1.000000 & 0.740000 & 1.000000 & 0.410000 & 0.194774 & 0.070000 \\
# has_belly_pattern::solid & False & True & 1.000000 & 0.170000 & 1.000000 & 0.350000 & 0.573465 & 0.745000 \\
# has_primary_color::white & True & False & 0.000000 & 0.670000 & 0.000000 & 0.550000 & 0.290126 & 0.205000 \\
# has_primary_color::buff & True & False & 0.000000 & 0.130000 & 0.000000 & 0.190000 & 0.191975 & 0.090000 \\
# has_crown_color::blue & True & False & 0.000000 & 0.020000 & 0.000000 & 0.050000 & 0.054971 & 0.050000 \\
# \bottomrule
# \end{tabular}

# %%
display_scrollable_dataframe(Full_df.sort_values(by=['Majority Label',"Label"],ascending=False))
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>Label</th>
#       <th>Majority Label</th>
#       <th>Joint MV</th>
#       <th>Joint NoN-MV</th>
#       <th>Sequential MV</th>
#       <th>Sequential NoN-MV</th>
#       <th>NoN-MV Label distribution</th>
#       <th>MV label ditribution</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>has_wing_color::white</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.97</td>
#       <td>1.0</td>
#       <td>0.85</td>
#       <td>0.260774</td>
#       <td>0.205</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>has_upperparts_color::white</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.93</td>
#       <td>1.0</td>
#       <td>0.80</td>
#       <td>0.232949</td>
#       <td>0.175</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>has_upperparts_color::buff</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.78</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>0.169410</td>
#       <td>0.125</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>has_underparts_color::brown</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.53</td>
#       <td>1.0</td>
#       <td>0.78</td>
#       <td>0.102732</td>
#       <td>0.060</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>has_upper_tail_color::black</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.63</td>
#       <td>1.0</td>
#       <td>0.68</td>
#       <td>0.256956</td>
#       <td>0.305</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>has_head_pattern::plain</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.66</td>
#       <td>1.0</td>
#       <td>0.92</td>
#       <td>0.263828</td>
#       <td>0.215</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>has_breast_color::brown</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.93</td>
#       <td>1.0</td>
#       <td>0.99</td>
#       <td>0.113590</td>
#       <td>0.065</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>has_bill_length::about_the_same_as_head</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.67</td>
#       <td>1.0</td>
#       <td>0.85</td>
#       <td>0.362233</td>
#       <td>0.340</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>has_size::medium_(9_-_16_in)</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>0.196386</td>
#       <td>0.185</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>has_shape::duck-like</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>0.061334</td>
#       <td>0.050</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>has_tail_pattern::solid</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.12</td>
#       <td>1.0</td>
#       <td>0.33</td>
#       <td>0.355616</td>
#       <td>0.430</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>has_wing_pattern::multi-colored</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.93</td>
#       <td>1.0</td>
#       <td>0.81</td>
#       <td>0.297336</td>
#       <td>0.220</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>has_upperparts_color::brown</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.64</td>
#       <td>1.0</td>
#       <td>0.67</td>
#       <td>0.243468</td>
#       <td>0.230</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>has_breast_pattern::solid</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.49</td>
#       <td>1.0</td>
#       <td>0.38</td>
#       <td>0.548269</td>
#       <td>0.645</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>has_eye_color::black</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.98</td>
#       <td>1.0</td>
#       <td>0.96</td>
#       <td>0.837462</td>
#       <td>0.960</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>has_under_tail_color::white</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>1.0</td>
#       <td>0.65</td>
#       <td>0.179080</td>
#       <td>0.160</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>has_back_pattern::multi-colored</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.74</td>
#       <td>1.0</td>
#       <td>0.41</td>
#       <td>0.194774</td>
#       <td>0.070</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>has_belly_pattern::solid</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>0.17</td>
#       <td>1.0</td>
#       <td>0.35</td>
#       <td>0.573465</td>
#       <td>0.745</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>has_wing_color::brown</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.62</td>
#       <td>0.0</td>
#       <td>0.57</td>
#       <td>0.269681</td>
#       <td>0.245</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>has_wing_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.45</td>
#       <td>0.0</td>
#       <td>0.47</td>
#       <td>0.182474</td>
#       <td>0.130</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>has_upperparts_color::black</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.54</td>
#       <td>0.0</td>
#       <td>0.63</td>
#       <td>0.391245</td>
#       <td>0.410</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>has_breast_pattern::striped</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.117153</td>
#       <td>0.075</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>has_back_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.68</td>
#       <td>0.0</td>
#       <td>0.28</td>
#       <td>0.153800</td>
#       <td>0.120</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>has_back_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.53</td>
#       <td>0.0</td>
#       <td>0.52</td>
#       <td>0.146335</td>
#       <td>0.110</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>has_upper_tail_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.23</td>
#       <td>0.0</td>
#       <td>0.58</td>
#       <td>0.123940</td>
#       <td>0.120</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>has_forehead_color::blue</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.0</td>
#       <td>0.01</td>
#       <td>0.050814</td>
#       <td>0.050</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>has_primary_color::white</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.67</td>
#       <td>0.0</td>
#       <td>0.55</td>
#       <td>0.290126</td>
#       <td>0.205</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>has_primary_color::buff</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.13</td>
#       <td>0.0</td>
#       <td>0.19</td>
#       <td>0.191975</td>
#       <td>0.090</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>has_crown_color::blue</td>
#       <td>True</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.02</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.054971</td>
#       <td>0.050</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>has_bill_shape::dagger</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.134968</td>
#       <td>0.085</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>has_bill_shape::hooked_seabird</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.05</td>
#       <td>0.063709</td>
#       <td>0.060</td>
#     </tr>
#     <

# %%
df=pd.DataFrame(Concept_dict).sort_values(by=['Majority Label',"Label"],ascending=False)
latex_table = df.to_latex(index=False)
print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# Concept & Label & Majority Label & Joint MV & Joint NoN-MV & Sequential MV & Sequential NoN-MV & NoN-MV Label distribution & MV label ditribution \\
# \midrule
# has_wing_color::white & True & True & 1.000000 & 0.970000 & 1.000000 & 0.850000 & 0.260774 & 0.205000 \\
# has_upperparts_color::white & True & True & 1.000000 & 0.930000 & 1.000000 & 0.800000 & 0.232949 & 0.175000 \\
# has_upperparts_color::buff & True & True & 1.000000 & 0.780000 & 1.000000 & 0.740000 & 0.169410 & 0.125000 \\
# has_underparts_color::brown & True & True & 1.000000 & 0.530000 & 1.000000 & 0.780000 & 0.102732 & 0.060000 \\
# has_upper_tail_color::black & True & True & 1.000000 & 0.630000 & 1.000000 & 0.680000 & 0.256956 & 0.305000 \\
# has_head_pattern::plain & True & True & 1.000000 & 0.660000 & 1.000000 & 0.920000 & 0.263828 & 0.215000 \\
# has_breast_color::brown & True & True & 1.000000 & 0.930000 & 1.000000 & 0.990000 & 0.113590 & 0.065000 \\
# has_bill_length::about_the_same_as_head & True & True & 1.000000 & 0.670000 & 1.000000 & 0.850000 & 0.362233 & 0.340000 \\
# has_size::medium_(9_-_16_in) & True & True & 1.000000 & 0.980000 & 1.000000 & 0.980000 & 0.196386 & 0.185000 \\
# has_shape::duck-like & True & True & 1.000000 & 0.980000 & 1.000000 & 0.980000 & 0.061334 & 0.050000 \\
# has_tail_pattern::solid & True & True & 1.000000 & 0.120000 & 1.000000 & 0.330000 & 0.355616 & 0.430000 \\
# has_wing_pattern::multi-colored & True & True & 1.000000 & 0.930000 & 1.000000 & 0.810000 & 0.297336 & 0.220000 \\
# has_upperparts_color::brown & False & True & 1.000000 & 0.640000 & 1.000000 & 0.670000 & 0.243468 & 0.230000 \\
# has_breast_pattern::solid & False & True & 1.000000 & 0.490000 & 1.000000 & 0.380000 & 0.548269 & 0.645000 \\
# has_eye_color::black & False & True & 1.000000 & 0.980000 & 1.000000 & 0.960000 & 0.837462 & 0.960000 \\
# has_under_tail_color::white & False & True & 1.000000 & 0.740000 & 1.000000 & 0.650000 & 0.179080 & 0.160000 \\
# has_back_pattern::multi-colored & False & True & 1.000000 & 0.740000 & 1.000000 & 0.410000 & 0.194774 & 0.070000 \\
# has_belly_pattern::solid & False & True & 1.000000 & 0.170000 & 1.000000 & 0.350000 & 0.573465 & 0.745000 \\
# has_wing_color::brown & True & False & 0.000000 & 0.620000 & 0.000000 & 0.570000 & 0.269681 & 0.245000 \\
# has_wing_color::buff & True & False & 0.000000 & 0.450000 & 0.000000 & 0.470000 & 0.182474 & 0.130000 \\
# has_upperparts_color::black & True & False & 0.000000 & 0.540000 & 0.000000 & 0.630000 & 0.391245 & 0.410000 \\
# has_breast_pattern::striped & True & False & 0.000000 & 0.010000 & 0.000000 & 0.050000 & 0.117153 & 0.075000 \\
# has_back_color::white & True & False & 0.000000 & 0.680000 & 0.000000 & 0.280000 & 0.153800 & 0.120000 \\
# has_back_color::buff & True & False & 0.000000 & 0.530000 & 0.000000 & 0.520000 & 0.146335 & 0.110000 \\
# has_upper_tail_color::white & True & False & 0.000000 & 0.230000 & 0.000000 & 0.580000 & 0.123940 & 0.120000 \\
# has_forehead_color::blue & True & False & 0.000000 & 0.010000 & 0.000000 & 0.010000 & 0.050814 & 0.050000 \\
# has_primary_color::white & True & False & 0.000000 & 0.670000 & 0.000000 & 0.550000 & 0.290126 & 0.205000 \\
# has_primary_color::buff & True & False & 0.000000 & 0.130000 & 0.000000 & 0.190000 & 0.191975 & 0.090000 \\
# has_crown_color::blue & True & False & 0.000000 & 0.020000 & 0.000000 & 0.050000 & 0.054971 & 0.050000 \\
# has_bill_shape::dagger & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.134968 & 0.085000 \\
# has_bill_shape::hooked_seabird & False & False & 0.000000 & 0.000000 & 0.000000 & 0.050000 & 0.063709 & 0.060000 \\
# has_bill_shape::all-purpose & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.391754 & 0.405000 \\
# has_bill_shape::cone & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.261452 & 0.245000 \\
# has_wing_color::grey & False & False & 0.000000 & 0.370000 & 0.000000 & 0.310000 & 0.300390 & 0.230000 \\
# has_wing_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.091703 & 0.060000 \\
# has_wing_color::black & False & False & 0.000000 & 0.570000 & 0.000000 & 0.590000 & 0.428487 & 0.410000 \\
# has_upperparts_color::grey & False & False & 0.000000 & 0.430000 & 0.000000 & 0.340000 & 0.289956 & 0.270000 \\
# has_upperparts_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.094503 & 0.080000 \\
# has_underparts_color::grey & False & False & 0.000000 & 0.020000 & 0.000000 & 0.060000 & 0.187224 & 0.100000 \\
# has_underparts_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.149474 & 0.140000 \\
# has_underparts_color::black & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.176790 & 0.155000 \\
# has_underparts_color::white & False & False & 0.000000 & 0.520000 & 0.000000 & 0.450000 & 0.390397 & 0.430000 \\
# has_underparts_color::buff & False & False & 0.000000 & 0.040000 & 0.000000 & 0.130000 & 0.183916 & 0.145000 \\
# has_breast_pattern::multi-colored & False & False & 0.000000 & 0.050000 & 0.000000 & 0.090000 & 0.185867 & 0.080000 \\
# has_back_color::brown & False & False & 0.000000 & 0.490000 & 0.000000 & 0.580000 & 0.197659 & 0.225000 \\
# has_back_color::grey & False & False & 0.000000 & 0.330000 & 0.000000 & 0.290000 & 0.243298 & 0.255000 \\
# has_back_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.071598 & 0.050000 \\
# has_back_color::black & False & False & 0.000000 & 0.290000 & 0.000000 & 0.230000 & 0.285969 & 0.270000 \\
# has_tail_shape::notched_tail & False & False & 0.000000 & 0.010000 & 0.000000 & 0.020000 & 0.297506 & 0.290000 \\
# has_upper_tail_color::brown & False & False & 0.000000 & 0.010000 & 0.000000 & 0.020000 & 0.145826 & 0.170000 \\
# has_upper_tail_color::grey & False & False & 0.000000 & 0.010000 & 0.000000 & 0.020000 & 0.185188 & 0.180000 \\
# has_upper_tail_color::buff & False & False & 0.000000 & 0.030000 & 0.000000 & 0.080000 & 0.107397 & 0.085000 \\
# has_head_pattern::eyebrow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.120292 & 0.050000 \\
# has_breast_color::grey & False & False & 0.000000 & 0.000000 & 0.000000 & 0.040000 & 0.186291 & 0.090000 \\
# has_breast_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.010000 & 0.136834 & 0.145000 \\
# has_breast_color::black & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.202833 & 0.165000 \\
# has_breast_color::white & False & False & 0.000000 & 0.140000 & 0.000000 & 0.080000 & 0.359094 & 0.370000 \\
# has_breast_color::buff & False & False & 0.000000 & 0.040000 & 0.000000 & 0.230000 & 0.175093 & 0.120000 \\
# has_throat_color::grey & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.164998 & 0.050000 \\
# has_throat_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.060000 & 0.112572 & 0.105000 \\
# has_throat_color::black & False & False & 0.000000 & 0.060000 & 0.000000 & 0.010000 & 0.220139 & 0.200000 \\
# has_throat_color::white & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.345521 & 0.370000 \\
# has_throat_color::buff & False & False & 0.000000 & 0.000000 & 0.000000 & 0.010000 & 0.140652 & 0.065000 \\
# has_bill_length::shorter_than_head & False & False & 0.000000 & 0.060000 & 0.000000 & 0.010000 & 0.561079 & 0.630000 \\
# has_forehead_color::brown & False & False & 0.000000 & 0.000000 & 0.000000 & 0.010000 & 0.175093 & 0.140000 \\
# has_forehead_color::grey & False & False & 0.000000 & 0.040000 & 0.000000 & 0.010000 & 0.202749 & 0.115000 \\
# has_forehead_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.020000 & 0.085256 & 0.075000 \\
# has_forehead_color::black & False & False & 0.000000 & 0.140000 & 0.000000 & 0.040000 & 0.323465 & 0.340000 \\
# has_forehead_color::white & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.137682 & 0.085000 \\
# has_under_tail_color::brown & False & False & 0.000000 & 0.040000 & 0.000000 & 0.130000 & 0.156345 & 0.150000 \\
# has_under_tail_color::grey & False & False & 0.000000 & 0.020000 & 0.000000 & 0.030000 & 0.204700 & 0.150000 \\
# has_under_tail_color::black & False & False & 0.000000 & 0.090000 & 0.000000 & 0.220000 & 0.317357 & 0.390000 \\
# has_under_tail_color::buff & False & False & 0.000000 & 0.040000 & 0.000000 & 0.020000 & 0.119952 & 0.085000 \\
# has_nape_color::brown & False & False & 0.000000 & 0.000000 & 0.000000 & 0.030000 & 0.174245 & 0.130000 \\
# has_nape_color::grey & False & False & 0.000000 & 0.010000 & 0.000000 & 0.000000 & 0.242365 & 0.165000 \\
# has_nape_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.079827 & 0.060000 \\
# has_nape_color::black & False & False & 0.000000 & 0.080000 & 0.000000 & 0.030000 & 0.264761 & 0.230000 \\
# has_nape_color::white & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.219800 & 0.185000 \\
# has_nape_color::buff & False & False & 0.000000 & 0.000000 & 0.000000 & 0.060000 & 0.155327 & 0.085000 \\
# has_belly_color::brown & False & False & 0.000000 & 0.030000 & 0.000000 & 0.110000 & 0.087971 & 0.055000 \\
# has_belly_color::grey & False & False & 0.000000 & 0.010000 & 0.000000 & 0.090000 & 0.169579 & 0.085000 \\
# has_belly_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.143536 & 0.145000 \\
# has_belly_color::black & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.145232 & 0.125000 \\
# has_belly_color::white & False & False & 0.000000 & 0.530000 & 0.000000 & 0.450000 & 0.373770 & 0.410000 \\
# has_belly_color::buff & False & False & 0.000000 & 0.020000 & 0.000000 & 0.090000 & 0.168222 & 0.115000 \\
# has_wing_shape::rounded-wings & False & False & 0.000000 & 0.090000 & 0.000000 & 0.080000 & 0.279352 & 0.425000 \\
# has_wing_shape::pointed-wings & False & False & 0.000000 & 0.020000 & 0.000000 & 0.060000 & 0.199525 & 0.150000 \\
# has_size::small_(5_-_9_in) & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.511537 & 0.630000 \\
# has_size::very_small_(3_-_5_in) & False & False & 0.000000 & 0.010000 & 0.000000 & 0.020000 & 0.238293 & 0.095000 \\
# has_shape::perching-like & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.486766 & 0.595000 \\
# has_back_pattern::solid & False & False & 0.000000 & 0.010000 & 0.000000 & 0.200000 & 0.365032 & 0.495000 \\
# has_back_pattern::striped & False & False & 0.000000 & 0.170000 & 0.000000 & 0.230000 & 0.159908 & 0.120000 \\
# has_tail_pattern::striped & False & False & 0.000000 & 0.060000 & 0.000000 & 0.130000 & 0.127672 & 0.065000 \\
# has_tail_pattern::multi-colored & False & False & 0.000000 & 0.220000 & 0.000000 & 0.230000 & 0.227859 & 0.130000 \\
# has_primary_color::brown & False & False & 0.000000 & 0.380000 & 0.000000 & 0.400000 & 0.249746 & 0.190000 \\
# has_primary_color::grey & False & False & 0.000000 & 0.270000 & 0.000000 & 0.320000 & 0.295640 & 0.215000 \\
# has_primary_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.150662 & 0.125000 \\
# has_primary_color::black & False & False & 0.000000 & 0.100000 & 0.000000 & 0.120000 & 0.355446 & 0.280000 \\
# has_leg_color::grey & False & False & 0.000000 & 0.000000 & 0.000000 & 0.010000 & 0.255599 & 0.225000 \\
# has_leg_color::black & False & False & 0.000000 & 0.000000 & 0.000000 & 0.010000 & 0.245674 & 0.275000 \\
# has_leg_color::buff & False & False & 0.000000 & 0.010000 & 0.000000 & 0.080000 & 0.159569 & 0.110000 \\
# has_bill_color::grey & False & False & 0.000000 & 0.040000 & 0.000000 & 0.040000 & 0.273583 & 0.125000 \\
# has_bill_color::black & False & False & 0.000000 & 0.100000 & 0.000000 & 0.080000 & 0.441805 & 0.490000 \\
# has_bill_color::buff & False & False & 0.000000 & 0.060000 & 0.000000 & 0.220000 & 0.146675 & 0.055000 \\
# has_crown_color::brown & False & False & 0.000000 & 0.000000 & 0.000000 & 0.010000 & 0.188327 & 0.145000 \\
# has_crown_color::grey & False & False & 0.000000 & 0.020000 & 0.000000 & 0.020000 & 0.214795 & 0.115000 \\
# has_crown_color::yellow & False & False & 0.000000 & 0.000000 & 0.000000 & 0.010000 & 0.071683 & 0.055000 \\
# has_crown_color::black & False & False & 0.000000 & 0.100000 & 0.000000 & 0.050000 & 0.326264 & 0.335000 \\
# has_crown_color::white & False & False & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 0.121564 & 0.075000 \\
# has_wing_pattern::solid & False & False & 0.000000 & 0.000000 & 0.000000 & 0.030000 & 0.284442 & 0.270000 \\
# has_wing_pattern::spotted & False & False & 0.000000 & 0.010000 & 0.000000 & 0.000000 & 0.075501 & 0.050000 \\
# has_wing_pattern::striped & False & False & 0.000000 & 0.040000 & 0.000000 & 0.160000 & 0.234730 & 0.200000 \\
# \bottomrule
# \end{tabular}
